# %% [markdown]
# <a href="https://colab.research.google.com/github/yuruojie777/NLP/blob/main/COMP5046_Lab09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Named Entity Recognition
#
# "The subtask of information extraction that seeks to locate and classify named entity mentions in unstructured text into pre-defined categories such as the person names, organizations, locations, medical codes, time expressions, quantities, monetary values, percentages, etc.”
#
# It is very common that sequence models, such as HMM, MEMM, CRF, are applied to named entity recognition. In this lab 09, we will train and test named entity recognition with sequence modeling, such as CRF.

# %% [markdown]
# ***Note***: Sample code in this labs require specific versions of some packages to be installed, which may cause dependency confilicts with some of the pre-installed packages in Colab. Thus, you may see some error messages indicating the dependency conflicts upon installation. These errors can be ignored and will not affect running of our sample codes since we will not use those conflicted packages.

# %%
# !pip install -U 'scikit-learn<0.24'
# !pip install urllib3==1.25.11
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
# Out:
# Collecting scikit-learn<0.24
#   Downloading scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 5.3 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (3.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24) (1.4.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.23.2 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.23.2 which is incompatible.
# Successfully installed scikit-learn-0.23.2
# Collecting urllib3==1.25.11
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 5.0 MB/s
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed urllib3-1.25.11

# %%
# read IOB tagged NER dataset as dataframe
df = pd.read_csv('https://drive.google.com/uc?id=1UPHg29593FCCNqec6RyYitjfoyY90UWN', encoding = "ISO-8859-1")
df.head(10)
# Out:
#     Sentence #           Word  POS    Tag
# 0  Sentence: 1      Thousands  NNS      O
# 1          NaN             of   IN      O
# 2          NaN  demonstrators  NNS      O
# 3          NaN           have  VBP      O
# 4          NaN        marched  VBN      O
# 5          NaN        through   IN      O
# 6          NaN         London  NNP  B-geo
# 7          NaN             to   TO      O
# 8          NaN        protest   VB      O
# 9          NaN            the   DT      O

# %%
set(df['Tag'].tolist())
# Out:
# {'B-art',
#  'B-eve',
#  'B-geo',
#  'B-gpe',
#  'B-nat',
#  'B-org',
#  'B-per',
#  'B-tim',
#  'I-art',
#  'I-eve',
#  'I-geo',
#  'I-gpe',
#  'I-nat',
#  'I-org',
#  'I-per',
#  'I-tim',
#  'O'}

# %% [markdown]
# In the data, you can see the different types of entities:
# * geo = Geographical Entity
# * org = Organization
# * per = Person
# * gpe = Geopolitical Entity
# * tim = Time indicator
# * art = Artifact
# * eve = Event
# * nat = Natural Phenomenon

# %% [markdown]
# ## Data Preprocessing
# There are too many NaN values in ‘Sentence #” column, fill NaN by preceding values.
# We have 47959 sentences that contain 35172 unique words and tagged by 17 tags.

# %%
df = df.fillna(method='ffill')
df['Sentence #'].nunique(), df.Word.nunique(), df.Tag.nunique()
# Out:
# (47959, 35172, 17)

# %%
df.groupby('Tag').size().reset_index(name='counts')
# Out:
#       Tag  counts
# 0   B-art     402
# 1   B-eve     308
# 2   B-geo   37644
# 3   B-gpe   15870
# 4   B-nat     201
# 5   B-org   20143
# 6   B-per   16990
# 7   B-tim   20333
# 8   I-art     297
# 9   I-eve     253
# 10  I-geo    7414
# 11  I-gpe     198
# 12  I-nat      51
# 13  I-org   16784
# 14  I-per   17251
# 15  I-tim    6528
# 16      O  887908

# %% [markdown]
# We will now train a CRF model for named entity recognition using sklearn-crfsuite on our dataset. As mentioned before, MEMM or CRF is often used for labeling or parsing of sequential data for named entity recognition.

# %%
# !pip install sklearn_crfsuite
# Out:
# Collecting sklearn_crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn_crfsuite) (0.8.9)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_crfsuite) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn_crfsuite) (1.15.0)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (965 kB)
#      |████████████████████████████████| 965 kB 5.2 MB/s
# Installing collected packages: python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.8 sklearn-crfsuite-0.3.6

# %% [markdown]
# ##Conditional random fields (CRF)

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
from collections import Counter

# %%
#Retrieving sentences with their POS and tags.
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s['Word'].values.tolist(), 
                                                           s['POS'].values.tolist(), 
                                                           s['Tag'].values.tolist())]
        self.grouped = self.data.groupby('Sentence #').apply(agg_func)
        self.sentences = [s for s in self.grouped]
        
    def get_next(self):
        try: 
            s = self.grouped['Sentence: {}'.format(self.n_sent)]
            self.n_sent += 1
            return s 
        except:
            return None
getter = SentenceGetter(df)
sentences = getter.sentences

# %% [markdown]
# We extract more features (word parts, simplified POS tags, lower/title/upper flags, features of nearby words) and convert them to sklearn-crfsuite format — each sentence should be converted to a list of dicts. The following code was taken from [sklearn-crfsuites official site](https://sklearn-crfsuite.readthedocs.io/en/latest/tutorial.html).

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
sent2features(sentences[0])[0]
# Out:
# {'+1:postag': 'IN',
#  '+1:postag[:2]': 'IN',
#  '+1:word.istitle()': False,
#  '+1:word.isupper()': False,
#  '+1:word.lower()': 'of',
#  'BOS': True,
#  'bias': 1.0,
#  'postag': 'NNS',
#  'postag[:2]': 'NN',
#  'word.isdigit()': False,
#  'word.istitle()': True,
#  'word.isupper()': False,
#  'word.lower()': 'thousands',
#  'word[-2:]': 'ds',
#  'word[-3:]': 'nds'}

# %%
# data splitting for training and testing

X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
# train a CRF model for named entity recognition using sklearn-crfsuite 
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %% [markdown]
# Because tag “O” (outside) is the most common tag and it will make our results look much better than they actual are. So we remove tag “O” when we evaluate classification metrics.

# %%
y = df.Tag.values
classes = np.unique(y)
classes = classes.tolist()
classes.pop()
classes
# Out:
# ['B-art',
#  'B-eve',
#  'B-geo',
#  'B-gpe',
#  'B-nat',
#  'B-org',
#  'B-per',
#  'B-tim',
#  'I-art',
#  'I-eve',
#  'I-geo',
#  'I-gpe',
#  'I-nat',
#  'I-org',
#  'I-per',
#  'I-tim']

# %%
#evaluation
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(y_test, y_pred, labels=classes))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['B-art', 'B-eve', 'B-geo', 'B-gpe', 'B-nat', 'B-org', 'B-per', 'B-tim', 'I-art', 'I-eve', 'I-geo', 'I-gpe', 'I-nat', 'I-org', 'I-per', 'I-tim'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
#               precision    recall  f1-score   support
#
#        B-art       0.45      0.12      0.19       143
#        B-eve       0.59      0.42      0.49       106
#        B-geo       0.86      0.91      0.88     12447
#        B-gpe       0.97      0.94      0.95      5284
#        B-nat       0.82      0.42      0.56        78
#        B-org       0.80      0.73      0.76      6615
#        B-per       0.85      0.82      0.84      5652
#        B-tim       0.93      0.88      0.90      6856
#        I-art       0.11      0.03      0.05       105
#        I-eve       0.38      0.22      0.28        93
#        I-geo       0.82      0.81      0.81      2520
#        I-gpe       0.91      0.62      0.74        69
#        I-nat       1.00      0.43      0.61        23
#        I-org       0.82      0.80      0.81      5597
#        I-per       0.85      0.90      0.87      5674
#        I-tim       0.84      0.74      0.79      2207
#
#    micro avg       0.86      0.85      0.85     53469
#    macro avg       0.75      0.61      0.66     53469
# weighted avg       0.86      0.85      0.85     53469

# %% [markdown]
# The following shows what our classifier learned. It is very likely that the beginning of a geographical entity (B-geo) will be followed by a token inside geographical entity (I-geo), but transitions to inside of an organization name (I-geo) from tokens with other labels are penalized hugely.

# %%
def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))
print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))
print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# B-nat  -> I-nat   6.934503
# I-art  -> I-art   6.260215
# B-art  -> I-art   5.881224
# I-eve  -> I-eve   5.847777
# B-eve  -> I-eve   5.586673
# I-tim  -> I-tim   5.204188
# I-org  -> I-org   4.782243
# I-gpe  -> I-gpe   4.699609
# B-tim  -> I-tim   4.636703
# B-org  -> I-org   4.282602
# O      -> O       3.813956
# B-per  -> I-per   3.698815
# I-geo  -> I-geo   3.685166
# B-gpe  -> I-gpe   3.597376
# B-geo  -> I-geo   3.516476
# I-per  -> I-per   3.245863
# I-nat  -> I-nat   2.954009
# I-geo  -> B-art   1.973397
# O      -> B-tim   1.748999
# O      -> B-per   1.620428
#
# Top unlikely transitions:
# I-org  -> I-geo   -4.259782
# I-org  -> I-per   -4.327937
# B-geo  -> B-geo   -4.426926
# B-per  -> I-org   -4.427218
# B-geo  -> I-gpe   -4.435073
# B-per  -> I-geo   -4.466408
# B-tim  -> B-tim   -4.518613
# B-org  -> I-geo   -4.575173
# B-geo  -> I-per   -4.793920
# B-org  -> I-per   -5.036090
# B-geo  -> I-org   -5.070524
# B-gpe  -> I-geo   -5.210003
# B-gpe  -> I-org   -5.287803
# B-gpe  -> B-gpe   -5.607401
# O      -> I-per   -5.956129
# I-per  -> B-per   -5.963596
# O      -> I-tim   -6.288495
# O      -> I-org   -6.908351
# O      -> I-geo   -7.883945
# B-per  -> B-per   -10.813935

# %% [markdown]
# #NER and Coreference Resolution with Spacy

# %% [markdown]
# Now, we will learn how to predict NER and Coreference Resolution with [Spacy](https://spacy.io/)

# %%
# !pip install -U spacy==2.1
# !python -m spacy download en
# Out:
# Collecting spacy==2.1
#   Downloading spacy-2.1.0-cp37-cp37m-manylinux1_x86_64.whl (27.7 MB)
#      |████████████████████████████████| 27.7 MB 66.9 MB/s
# Collecting preshed<2.1.0,>=2.0.1
#   Downloading preshed-2.0.1-cp37-cp37m-manylinux1_x86_64.whl (82 kB)
#      |████████████████████████████████| 82 kB 377 kB/s
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1) (1.21.6)
# Collecting jsonschema<3.0.0,>=2.6.0
#   Downloading jsonschema-2.6.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: srsly<1.1.0,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1) (1.0.5)
# Collecting blis<0.3.0,>=0.2.2
#   Downloading blis-0.2.4-cp37-cp37m-manylinux1_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 38.5 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1) (1.0.6)
# Collecting thinc<7.1.0,>=7.0.2
#   Downloading thinc-7.0.8-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 34.1 MB/s
# Collecting plac<1.0.0,>=0.9.6
#   Downloading plac-0.9.6-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy==2.1) (0.9.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1) (3.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from thinc<7.1.0,>=7.0.2->spacy==2.1) (4.64.0)
# Installing collected packages: preshed, plac, blis, thinc, jsonschema, spacy
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.6
#     Uninstalling preshed-3.0.6:
#       Successfully uninstalled preshed-3.0.6
#   Attempting uninstall: plac
#     Found existing installation: plac 1.1.3
#     Uninstalling plac-1.1.3:
#       Successfully uninstalled plac-1.1.3
#   Attempting uninstall: blis
#     Found existing installation: blis 0.4.1
#     Uninstalling blis-0.4.1:
#       Successfully uninstalled blis-0.4.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbclient 0.6.0 requires jupyter-client>=6.1.5, but you have jupyter-client 5.3.5 which is incompatible.
# en-core-web-sm 2.2.5 requires spacy>=2.2.2, but you have spacy 2.1.0 which is incompatible.
# altair 4.2.0 requires jsonschema>=3.0, but you have jsonschema 2.6.0 which is incompatible.
# Successfully installed blis-0.2.4 jsonschema-2.6.0 plac-0.9.6 preshed-2.0.1 spacy-2.1.0 thinc-7.0.8
# Collecting en_core_web_sm==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz (11.1 MB)
#      |████████████████████████████████| 11.1 MB 5.2 MB/s
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.1.0-py3-none-any.whl size=11074433 sha256=f53e9c62fcd608fa31124c9b61394c369cd5ab0f1248e3f2e5b0706b32a2793b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-alo07hbp/wheels/59/4f/8c/0dbaab09a776d1fa3740e9465078bfd903cc22f3985382b496
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
from pprint import pprint

import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm

# %% [markdown]
# ##Named Entity Recognition with Spacy
#
# The following lines show how to build named entity recognizer with SpaCy, to identify the names of things, such as persons, organizations, or locations. SpaCy’s named entity recognition has been trained on the [OntoNotes 5 corpus](https://catalog.ldc.upenn.edu/LDC2013T19) and it supports the following entity types: [spacy docs](https://spacy.io/models/en#en_core_web_sm) (See the *label scheme* section）

# %%
# loading pre-trained model of NER
nlp = en_core_web_sm.load()

# %%
# !pip install wikipedia
import wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wikipedia) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=e3302445dbbfbfcab93b9e6f908eac7d747a722d0575342a66a9abfadee68216
#   Stored in directory: /root/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %% [markdown]
# We will extract a wikipedia page (with Barack Obama) to test NER with Spacy. There are around 2171 entities in the page.

# %%
# get the wikipedia page of Barack Obama
wikip = wikipedia.page("Barack_Obama")
article=nlp(wikip.content)
len(article.ents)
# Out:
# 2018

# %%
# count the number of entities by type found from wikipedia page
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'CARDINAL': 97,
#          'DATE': 472,
#          'EVENT': 19,
#          'FAC': 17,
#          'GPE': 369,
#          'LANGUAGE': 3,
#          'LAW': 29,
#          'LOC': 26,
#          'MONEY': 25,
#          'NORP': 118,
#          'ORDINAL': 59,
#          'ORG': 373,
#          'PERCENT': 33,
#          'PERSON': 342,
#          'PRODUCT': 7,
#          'QUANTITY': 3,
#          'TIME': 3,
#          'WORK_OF_ART': 23})

# %%
# getting the top 10 words recognised as named entity
items = [x.text for x in article.ents]
Counter(items).most_common(10)
# Out:
# [('Obama', 204),
#  ('U.S.', 51),
#  ('first', 42),
#  ('the United States', 26),
#  ('American', 16),
#  ('Chicago', 16),
#  ('Senate', 14),
#  ('Barack Obama', 14),
#  ('Democratic', 13),
#  ('Congress', 13)]

# %%
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# Barack Hussein Obama II ( (listen) bə-RAHK hoo-SAYN oh-BAH-mə;

# %%
# display each tag of the sentence
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[0]])
# Out:
# [(Barack, 'B', 'PERSON'), (Hussein, 'I', 'PERSON'), (Obama, 'I', 'PERSON'), (II, 'I', 'PERSON'), ((, 'O', ''), ((, 'O', ''), (listen, 'O', ''), (), 'O', ''), (bə, 'O', ''), (-, 'O', ''), (RAHK, 'O', ''), (hoo, 'O', ''), (-, 'O', ''), (SAYN, 'O', ''), (oh, 'O', ''), (-, 'O', ''), (BAH, 'O', ''), (-, 'O', ''), (mə, 'O', ''), (;, 'O', '')]

# %%
# display whole sentences using render()
displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Barack Hussein Obama II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ( (listen) bə-RAHK hoo-SAYN oh-BAH-mə;, born
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     August 4, 1961
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  politician who served as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     44th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ., A member of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Democratic Party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     African
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# -American  president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ., He previously served as a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  senator from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Illinois
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and as an
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Illinois
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  state senator from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1997
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </br>,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -we

# %% [markdown]
# ## Coreference Resolution with mention-ranking model and Spacy

# %% [markdown]
# This coreference resolution module is based on the spaCy parser and uses the neural net **mention-ranking scoring model** described in [Deep Reinforcement Learning for Mention-Ranking Coreference Models](https://cs.stanford.edu/people/kevclark/resources/clark-manning-emnlp2016-deep.pdf) by Kevin Clark and Christopher D. Manning, EMNLP 2016.

# %%
# !pip install neuralcoref
# Out:
# Collecting neuralcoref
#   Downloading neuralcoref-4.0-cp37-cp37m-manylinux1_x86_64.whl (286 kB)
#      |████████████████████████████████| 286 kB 5.2 MB/s
# Requirement already satisfied: spacy>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref) (2.1.0)
# Collecting boto3
#   Downloading boto3-1.22.3-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 49.4 MB/s
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2021.10.8)
# Requirement already satisfied: thinc<7.1.0,>=7.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (7.0.8)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (0.9.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (0.9.1)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (0.2.4)
# Requirement already satisfied: srsly<1.1.0,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (2.0.6)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (2.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (1.0.6)
# Requirement already satisfied: jsonschema<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.0->neuralcoref) (2.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from thinc<7.1.0,>=7.0.2->spacy>=2.1.0->neuralcoref) (4.64.0)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s
# Collecting botocore<1.26.0,>=1.25.3
#   Downloading botocore-1.25.3-py3-none-any.whl (8.7 MB)
#      |████████████████████████████████| 8.7 MB 9.2 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.26.0,>=1.25.3->boto3->neuralcoref) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.26.0,>=1.25.3->boto3->neuralcoref) (1.15.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3, neuralcoref
# Successfully installed boto3-1.22.3 botocore-1.25.3 jmespath-1.0.0 neuralcoref-4.0 s3transfer-0.5.2

# %%
import neuralcoref
import spacy
# Out:
# 100%|██████████| 40155833/40155833 [00:01<00:00, 29954921.71B/s]

# %%
# Load your usual SpaCy model (one of SpaCy English models)
nlp = spacy.load('en')

# Load NeuralCoref and add it to the pipe of SpaCy's model
coref = neuralcoref.NeuralCoref(nlp.vocab)
nlp.add_pipe(coref, name='neuralcoref')

# You can now use NeuralCoref with the wikipedia content that we extracted in the previous section and its annotations.
doc = nlp(wikip.content)

doc._.has_coref
doc._.coref_clusters
# Out:
# [the United States: [the United States, the United States],
#  Obama: [Obama, He, Obama, he, he, he, he, he, he, Obama, his, his, his, his, he, Obama, his, he, Obama, his, he, he, Obama, Obama, his, his, Obama, his, his, His, his, Obama, his],
#  Illinois: [Illinois, Illinois],
#  Chicago: [Chicago, Chicago],
#  the University of Chicago Law School: [the University of Chicago Law School, Punahou School],
#  the Illinois Senate: [the Illinois Senate, the U.S. Senate, March Senate, Senate, the Senate],
#  his landslide November election to the Senate: [his landslide November election to the Senate, the general election],
#  the Dodd–Frank Wall Street Reform and Consumer Protection Act: [the Dodd–Frank Wall Street Reform and Consumer Protection Act, The American Recovery and Reinvestment Act and Tax Relief, Unemployment Insurance Reauthorization, and Job Creation Act],
#  American: [American, American],
#  Obama: [Obama, He, He, Obama, he, His, He, he],
#  the Supreme Court: [the Supreme Court, the Court],
#  Iraq: [Iraq, Iraq],
#  U.S.: [U.S., U.S., U.S.],
#  the 2016 U.S. elections: [the 2016 U.S. elections, the 2018 midterm elections],
#  Obama: [Obama, Obama, Obama, him, Obama, Obama, Obama, He, He, His, Obama, Obama, his, Obama, Obama, Obama Sr, Obama, Obama, Obama, Obama, Obama, Obama, Obama, his, Obama, his, he, he, He, Obama, he, Obama, his, he, Obama, he, his, Obama, his, Obama, he, his, Obama, his, He, Obama, Obama, Obama, Obama, Obama, he, he, he, He, his, he, Obama, He, he, his, he, Obama, Obama, Obama, Obama, Obama, Obama, his, He, he, He, his, He, his, his, his, Obama, his, he, Obama, Obama, his, Obama, Obama, Obama, Obama, he, He, He, Obama, he, he, his, Obama, He, his, his, his, he, he, he, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, He, Obama, He, he, Obama, He, his, Obama, his, Obama, his, Obama, his, He, Obama, his, Obama, He, his, Obama, him, his, Obama, His, his, Obama, Obama, Obama, He, his, Senator Obama, He, President Bush, Obama, its, Obama, Obama, He, Obama, Obama, he, He, Obama, He, Obama, his, his, Obama, his, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, He, Obama, his, He, Obama, his, he, his, he, Obama, Obama, Obama, him, Obama, Obama, Barack Obama, Obama, Obama, He, Obama, he, Obama, Obama, his, He, Obama, Obama, Obama, him, Obama, He, Obama, He, Obama, Obama, he, Obama, Obama, Obama, Obama, Obama, Obama, he, his, he, he, he, Obama, Obama, Obama, Obama, Obama, Obama, Obama, his, He, Obama, Obama, Obama, President Obama, Obama, Obama, Obama, Obama, Obama, He, Obama, Obama, Obama, he, Obama, Obama, his, Obama, Obama, his, He, his, his, Obama, Obama, Obama, he, Obama, Obama, Obama, his, Obama, his, Obama, Obama, Obama, Obama, he, Obama, Obama, Obama, Obama, Obama, President Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, He, his, Obama, Obama, Obama, Obama, he, Obama, President Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, President Obama, Obama, Obama, He, He, He, his, Obama, his, Obama, Obama, he, he, Obama, he, he, Obama, Obama, Obama, Obama, Obama, his, his, his, Obama, his, Obama, his, he, Obama, his, He, his, His, his, his, Obama, his, Obama, Obama, Obama, Obama, Obama, Obama, his, Obama, Obama, Obama, Obama, Obama, his, Obama, Obama, Obama, Obama, Obama, Obama, Obama, He, his, his, his, his, his, Obama, Michelle Obama, Michelle Obama, Obama, Obama, he, himself, Obama, his, he, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, Obama, his, Obama, his, Barack Obama, Obama, Obama, builder."During Obama, Obama, Obama, Obama, Obama, Obama, him, Obama, Barack Obama, Barack Obama, Barack Obama, Barack Obama, Obama, Barack Obama, Barack Obama, Barack Obama, Barack Obama, Barack Obama, Barack Obama, Barack Obama, Barack Obama, Barack Obama],
#  Honolulu: [Honolulu, Honolulu, Honolulu],
#  Hawaii: [Hawaii, Hawaii, Hawaii, Hawaii, Hawaii, Hawaii, Hawaii, Hawaii, Hawaii, Hawaii, Hawaii],
#  an American mother and a Kenyan father: [an American mother and a Kenyan father, His mother, Ann Dunham (1942–1995), she],
#  Obama's father: [Obama's father, his father, Barack's father, his, He, he, my father, he, He, his, his, he, his, His, My Father],
#  The couple married in Wailuku, Hawaii, on February 2, 1961, six months before Obama was born: [The couple married in Wailuku, Hawaii, on February 2, 1961, six months before Obama was born, he, his],
#  Barack: [Barack, Barack],
#  Barack and his mother: [Barack and his mother, they],
#  Washington: [Washington, Washington],
#  Obama Sr.: [Obama Sr., he, He, his, he, his, me],
#  the University of Hawaii: [the University of Hawaii, the University of Hawaii],
#  Lolo: [Lolo, Lolo],
#  Indonesia: [Indonesia, Indonesia, Indonesia, Indonesia, Indonesia, Indonesia],
#  The family: [The family, they],
#  Obama: [Obama, his, his, he, his, his, he, his, Obama, him, him, his, He, he, his],
#  his mother: [his mother, his mother, his mother, his mother, His mother, Obama's mother, her, her, his mother, my mother, she],
#  his stepfather: [his stepfather, Obama's stepfather],
#  (Maya Soetoro-Ng) and seven other half-siblings from his Kenyan father's family: [(Maya Soetoro-Ng) and seven other half-siblings from his Kenyan father's family, them],
#  his Kenyan father: [his Kenyan father, his father, My Father, My Father],
#  the presidency: [the presidency, his presidency],
#  anthropologist Sheila Miyoshi Jager: [anthropologist Sheila Miyoshi Jager, he, He, her, Jager, her, him, his, he],
#  Chicago: [Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago, Chicago],
#  Michelle Robinson: [Michelle Robinson, Robinson, she, him, his, Michelle],
#  the Chicago law firm of Sidley Austin: [the Chicago law firm of Sidley Austin, the firm],
#  Sidley Austin: [Sidley Austin, Sidley Austin],
#  They: [They, their],
#  The Obama daughters: [The Obama daughters, they, the girls],
#  Washington, D.C.: [Washington, D.C., Washington, D.C.],
#  Bo: [Bo, Bo],
#  his childhood and adolescence: [his childhood and adolescence, them, their],
#  the White House: [the White House, the White House],
#  the team: [the team, their],
#  the Obama family: [the Obama family, the Obama family, the family],
#  2005—mostly: [2005—mostly, his, his, he, his],
#  a charity assisting wounded veterans' families: [a charity assisting wounded veterans' families, them],
#  Jesus Christ: [Jesus Christ, Jesus Christ, Christ],
#  church: [church, the church],
#  others: [others, they],
#  Christ pastor Jeremiah Wright: [Christ pastor Jeremiah Wright, Wright],
#  Trinity: [Trinity, Trinity],
#  he: [he, he, he, him, me, him],
#  these: [these, them],
#  Harvard Law School: [Harvard Law School, Harvard Law School],
#  the Harvard Law Review: [the Harvard Law Review, the Harvard Law Review],
#  Harvard: [Harvard, Harvard],
#  the University of Chicago Law School: [the University of Chicago Law School, the University of Chicago Law School],
#  his: [his, He],
#  Illinois: [Illinois, Illinois, Illinois, Illinois, Illinois, Illinois],
#  it: [it, its],
#  Crain's Chicago Business: [Crain's Chicago Business, its],
#  === Civil Rights attorney: [=== Civil Rights attorney, He, he, he],
#  Citibank Federal Savings Bank: [Citibank Federal Savings Bank, Citibank Federal Savings Bank],
#  the Illinois Senate: [the Illinois Senate, the Illinois Senate, the Illinois Senate, the Illinois Senate's, the U.S. Senate, the Illinois Senate, the U.S. Senate, U.S. Senate, U.S. Senate, Senate, U.S. Senate, Senate, Senate, the Senate, Senate, the U.S. Senate, his Senate, Senate],
#  the general election: [the general election, the general election, the general election, the general election, the general election],
#  the United States: [the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, the United States, America, America, America, the United States, the United States, the United States, the United States],
#  the United States House of Representatives: [the United States House of Representatives, the White House],
#  drivers: [drivers, they],
#  his 2004 general election campaign for the U.S. Senate: [his 2004 general election campaign for the U.S. Senate, her campaign],
#  November 2004: [November 2004, November 2004],
#  his election to the U.S. Senate: [his election to the U.S. Senate, the election],
#  a 2004 U.S. Senate race: [a 2004 U.S. Senate race, the race, the race],
#  the Iraq War: [the Iraq War, the war, the war, the Iraq War],
#  the national Democratic Party: [the national Democratic Party, the Democratic Party, the Democratic Party, the Democratic Party, the Democratic Party],
#  the 2004 Democratic National Convention: [the 2004 Democratic National Convention, the Democratic National Convention],
#  His speech: [His speech, the speech, his victory speech],
#  Alan Keyes: [Alan Keyes, He],
#  John McCain: [John McCain, McCain, he, his, McCain, McCain, McCain],
#  December 2006: [December 2006, December 2006],
#  January 2007: [January 2007, January 2007],
#  Obama and Senator Feingold: [Obama and Senator Feingold, Obama and McCain],
#  an amendment to the Defense Authorization Act to add safeguards for personality-disorder military discharges: [an amendment to the Defense Authorization Act to add safeguards for personality-disorder military discharges, This amendment],
#  the State Children's Health Insurance Program: [the State Children's Health Insurance Program, the State Children's Health Insurance Program, the Public–Private Investment Program],
#  Mahmoud Abbas: [Mahmoud Abbas, Abbas, he],
#  the presidency: [the presidency, the presidency],
#  The choice of the announcement site: [The choice of the announcement site, it],
#  Abraham Lincoln: [Abraham Lincoln, his],
#  the Democratic Party presidential primaries: [the Democratic Party presidential primaries, the Democratic Party presidential primaries],
#  Senator Hillary Clinton: [Senator Hillary Clinton, Clinton, her, Hillary Clinton, her, she, Bill Clinton, his, his, former President Bill Clinton, the 44th president, his, He],
#  Delaware Senator Joe Biden: [Delaware Senator Joe Biden, his, Biden, Joe Biden, Biden],
#  Invesco Field: [a field, Invesco Field],
#  the Democratic National Convention in Denver, Colorado: [the Democratic National Convention in Denver, Colorado, the Democratic National Convention in Charlotte, North Carolina, Obama and Joe Biden],
#  Chicago: [Chicago, Chicago],
#  United States: [United States, United States],
#  the Democratic Party candidates for president and vice president in the general election: [the Democratic Party candidates for president and vice president in the general election, Their],
#  Congress: [Congress, Congress, Congress, its, Congress, Congress, Congress, Congress, Congress, Congress, the U.S. Congress's],
#  March 2009: [March 2009, March 2009, March 2009, March 2009],
#  the Supreme Court: [the Supreme Court, Supreme Court, the Court, the Supreme Court],
#  Sonia Sotomayor: [Sonia Sotomayor, she, She],
#  Executive Order 13506: [Executive Order 13506, him],
#  the President Valerie Jarrett: [the President Valerie Jarrett, Jarrett],
#  the White House Task Force: [the White House Task Force, the Task Force, The Task Force],
#  the ban: [the ban, the ban],
#  his: [his, his, he, his, his],
#  U.S.: [U.S., U.S., the U.S., U.S.],
#  American: [American, American],
#  the American Recovery and Reinvestment Act of 2009, a $787 billion economic stimulus package aimed at helping the economy recover from the deepening worldwide recession: [the American Recovery and Reinvestment Act of 2009, a $787 billion economic stimulus package aimed at helping the economy recover from the deepening worldwide recession, The act],
#  the economy: [the economy, the economy, the economy, The economy of the United States, it],
#  Treasury: [Treasury, the Treasury],
#  Chrysler: [Chrysler, Chrysler, the company],
#  the White House: [the White House, the House, the House, the White House, the White House, the White House],
#  the U.S. government: [the U.S. government, the federal government, the Iranian government],
#  spending and loan guarantees from the Federal Reserve and the Department of the Treasury: [spending and loan guarantees from the Federal Reserve and the Department of the Treasury, These guarantees],
#  the Federal Reserve: [the Federal Reserve, the Federal Reserve, its],
#  the bipartisan Budget Control Act of 2011: [the bipartisan Budget Control Act of 2011, The legislation, the legislation],
#  The unemployment rate: [The unemployment rate, the unemployment rate, it, the unemployment rate, the unemployment rate],
#  the fourth quarter: [the fourth quarter, the first quarter, the fourth quarter, the first quarter],
#  the rest of the year: [the rest of the year, the rest of the year],
#  the year: [the year, the year],
#  The CBO: [The Congressional Budget Office (CBO) and a broad range of economists credit Obama's stimulus plan for economic growth, The CBO, the CBO],
#  the stimulus bill: [the stimulus bill, the stimulus bill],
#  a compromise deal with the Congressional Republican leadership that included a temporary, two-year extension of the 2001 and 2003 income tax rates, a one-year payroll tax reduction, continuation of unemployment benefits, and a new rate and exemption amount for estate taxes: [a compromise deal with the Congressional Republican leadership that included a temporary, two-year extension of the 2001 and 2003 income tax rates, a one-year payroll tax reduction, continuation of unemployment benefits, and a new rate and exemption amount for estate taxes, The compromise],
#  the Gulf of Mexico: [the Gulf of Mexico, the Gulf],
#  the Keystone XL pipeline: [the Keystone XL pipeline, it, the pipeline],
#  the 1953 Outer Continental Shelf Act: [the 1953 Outer Continental Shelf Act, the Antiquities Act, the Religious Freedom Restoration Act],
#  his presidency: [his presidency, his presidency, his presidency],
#  ===
#
#  Obama: [===
#
#  Obama, He, His],
#  people: [people, their, they],
#  His proposal: [His proposal, It, it],
#  a government insurance plan, also known as the public option, to compete with the corporate insurance sector as a main component to lowering costs and improving quality of health care: [a government insurance plan, also known as the public option, to compete with the corporate insurance sector as a main component to lowering costs and improving quality of health care, The plan],
#  insurers: [insurers, them],
#  U.S.: [U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., the U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., U.S., the U.S., U.S., the U.S., U.S., U.S., U.S.],
#  a health care bill featuring the public option: [a health care bill featuring the public option, its own bill—, the bill],
#  the Senate: [the Senate, its, the Senate],
#  insurance premiums for people making up to 400 percent of the FPL ($88,000 for family of four in 2010): [insurance premiums for people making up to 400 percent of the FPL ($88,000 for family of four in 2010), their],
#  White House: [White House, White House],
#  White House and CBO figures: [White House and CBO figures, their],
#  Medicare: [Medicare, Medicare],
#  those who do not obtain health insurance: [those who do not obtain health insurance, they],
#  March 2010: [March 2010, March 2010],
#  the Supreme Court: [the Supreme Court, the Court, the Court],
#  the U.S. Congress: [the U.S. Congress, the U.S. congress],
#  closely-held" for-profit corporations: [closely-held" for-profit corporations, them],
#  Europe: [Europe, Europe],
#  the Muslim world: [the Muslim world, the world, the world, the world, the world],
#  Iran: [Iran, Iran],
#  Yemen: [Yemen, Yemen, Yemen],
#  Anwar al-Awlaki: [Anwar al-Awlaki, Awlaki, Awlaki, Awlaki],
#  His teenage son and young daughter, also Americans: [His teenage son and young daughter, also Americans, they],
#  the Saudis: [the Saudis, their],
#  Saudi Arabia: [Saudi Arabia, Saudi Arabia, Saudi Arabia],
#  the Obama administration: [the Obama administration, The Obama administration, the Obama administration, The Obama administration, the Obama Administration, the Obama administration, the Obama administration, The administration, the Obama administration, The Obama administration, the Obama administration],
#  Iraq: [Iraq, Iraq, Iraq, Iraq, Iraq, Iraq, Iraq],
#  ISIS: [ISIS, ISIS, ISIS],
#  the battlefield: [the battlefield, the battlefield],
#  War in Afghanistan =: [War in Afghanistan =, the war, Syrian Civil War =, the Syrian Civil War],
#  Afghanistan: [Afghanistan, Afghanistan, Afghanistan, Afghanistan, Afghanistan, Afghanistan, Afghanistan],
#  his: [his, He, he, He],
#  McChrystal: [McChrystal, McChrystal, McChrystal],
#  July 2011: [July 2011, July 2010],
#  the U.S. military: [the U.S. military, the U.S. military],
#  Israel: [Israel, Israel, Israel, Israel, itself, Israel, Israel, it, the Israeli government, its, the Libyan government, its, its, the government, the Assad government],
#  a public stance against plans by the government of Israeli Prime Minister Benjamin Netanyahu to continue building Jewish housing projects in predominantly Arab neighborhoods of East Jerusalem: [a public stance against plans by the government of Israeli Prime Minister Benjamin Netanyahu to continue building Jewish housing projects in predominantly Arab neighborhoods of East Jerusalem, This stance],
#  Israeli Prime Minister Benjamin Netanyahu: [Israeli Prime Minister Benjamin Netanyahu, Netanyahu, his, He, Netanyahu, Israeli Prime Minister Benjamin Netanyahu],
#  his country: [his country, the country],
#  the Iran Nuclear Deal: [the Iran Nuclear Deal, the deal, it],
#  Libya: [Libya, Libya, Libya, Libya],
#  protests in Libya: [protests in Libya, They],
#  long-time dictator Muammar Gaddafi: [long-time dictator Muammar Gaddafi, Gaddafi, Gaddafi],
#  the U.S. Senate: [the U.S. Senate, the U.S. Senate],
#  NATO: [NATO, NATO],
#  President Assad: [President Assad, Assad, Assad, the President],
#  CIA: [CIA, the CIA, CIA],
#  Syria: [Syria, Syria],
#  intelligence: [intelligence, they],
#  Osama bin Laden: [Osama bin Laden, He, bin Laden, bin Laden, bin Laden's, Osama bin Laden],
#  a large compound in Abbottabad, Pakistan, a suburban area 35 miles (56 km) from Islamabad: [a large compound in Abbottabad, Pakistan, a suburban area 35 miles (56 km) from Islamabad, the compound, the compound],
#  CIA head Leon Panetta: [CIA head Leon Panetta, his],
#  a "surgical raid" to be conducted by United States Navy SEALs: [a "surgical raid" to be conducted by United States Navy SEALs, The operation],
#  the President's announcement from Washington, DC: [the President's announcement from Washington, DC, the announcement],
#  New York City's: [New York City's, Vatican City],
#  Bill Clinton: [Bill Clinton, Bill Clinton's, Bill Clinton],
#  George W. Bush: [George W. Bush, Bush],
#  Iran: [Iran, Iran, it, Iran, Iran],
#  a deal: [a deal, The deal, the deal, the deal, the deal],
#  Ronald Reagan: [Ronald Reagan, Ronald Reagan, Ronald Reagan's],
#  Cuba: [Cuba, Cuba, Cuba, Cuba, Cuba, Cuba],
#  the United States and Cuba: [the United States and Cuba, Cuba and the United States],
#  Pope Francis: [Pope Francis, Pope Francis],
#  the Cuban Thaw: [the Cuban Thaw, the Cuban Thaw],
#  Havana: [Havana, Havana],
#  My Father: [his father, My Father, His, his],
#  Hiroshima: [Hiroshima, Hiroshima, Hiroshima],
#  Russia: [Russia, Russia, Russia, Russia, Russia],
#  Russian President Dmitry Medvedev: [Russian President Dmitry Medvedev, Medvedev],
#  the New START treaty: [the New START treaty, it],
#  those of African-American politicians who launched their careers in the 1960s through participation in the civil rights movement: [those of African-American politicians who launched their careers in the 1960s through participation in the civil rights movement, their],
#  his presidency: [his presidency, his presidency, his presidency, his presidency, the Trump presidency],
#  the Year: [the year, the Year],
#  a small poll bounce: [a small poll bounce, This bounce],
#  his approval numbers: [his approval numbers, they],
#  Gallup: [Gallup, Gallup],
#  most people: [most people, their],
#  His concession speech after the New Hampshire primary was set to music by independent artists as the music video: [His concession speech after the New Hampshire primary was set to music by independent artists as the music video, his speech],
#  YouTube: [YouTube, its],
#  a Daytime Emmy Award: [a Daytime Emmy Award, this award, The award],
#  Time magazine: [Time magazine, its],
#  Obama's Peace Prize: [Obama's peace prize, his, He, Obama's Peace Prize],
#  Some neoconservatives: [Some neoconservatives, they],
#  the Nobel Peace Prize: [the Nobel Peace Prize, Obama's Nobel Prize],
#  office: [office, the office],
#  Donald Trump: [Donald Trump, Trump, his, President Trump, President Trump, his, his, Trump, Trump, he, he],
#  his: [his, His, he],
#  Chicago: [Chicago, Chicago, Chicago, Chicago],
#  Senate: [Senate, Senate],
#  Senate Republicans: [Senate Republicans, their, Senate Republicans],
#  a health care bill to replace the Affordable Care Act: [a health care bill to replace the Affordable Care Act, the bill],
#  the Affordable Care Act: [the Affordable Care Act, the Affordable Care Act],
#  Goalkeepers, Obama: [Goalkeepers, Obama, his],
#  Bill Clinton, and George W. Bush: [Bill Clinton, and George W. Bush, Bill Clinton, and George W. Bush],
#  George W. Bush: [George W. Bush, George W. Bush],
#  the Obama Foundation: [the Obama Foundation, the Obama Foundation],
#  the Obama Foundation in Chicago: [the Obama Foundation in Chicago, the foundation],
#  his time in office: [his time in office, his time in office],
#  Barack: [Barack, Barack, Barack, Barack, Barack],
#  Barack and Michelle Obama: [Barack and Michelle Obama, Barack and Michelle Obama],
#  Netflix: [Netflix, Netflix],
#  our: [our, our, our],
#  the crime: [the crime, the crime],
#  Penguin Random House: [Penguin Random House, the White House],
#  their: [their, their],
#  Regina Hicks: [Regina Hicks, his, his],
#  the Health Care and Education Reconciliation Act: [the Health Care and Education Reconciliation Act, it],
#  the Obama administration: [the Obama administration, his administration],
#  his: [his, his],
#  the Dodd–Frank Wall Street Reform and Consumer Protection Act: [the Dodd–Frank Wall Street Reform and Consumer Protection Act, it, the National Defense Authorization Act for Fiscal Year 2010, which contained in it the Matthew Shepard and James Byrd Jr. Hate Crimes Prevention Act, the first addition to existing federal hate crime law in the United States since Democratic President Bill Clinton signed into law the Church Arson Prevention Act of 1996],
#  the Matthew Shepard and James Byrd Jr. Hate Crimes Prevention Act: [the Matthew Shepard and James Byrd Jr. Hate Crimes Prevention Act, The Matthew Shepard and James Byrd Jr. Hate Crimes Prevention Act],
#  Matthew Shepard: [Matthew Shepard, The Matthew Shepard],
#  existing federal hate crime law in the United States: [existing federal hate crime law in the United States, the law],
#  his presidency: [his presidency, his presidency, Obama's presidency],
#  Julian Zelizer's: [Julian Zelizer's, his, His],
#  The Barack Obama Presidential Center: [The Barack Obama Presidential Center, It],
#  the Barack Obama administration
#  SPEECH Act
#  : [the Barack Obama administration
#  SPEECH Act
#  , It],
#  Barack Obama
#  : [Barack Obama
#  , Barack Obama
#  ]]

# %% [markdown]
# #Bi-LSTM CRF
# Here, we introduce a pytorch version of NER on Bi-LSTM CRF from Pytorch official document: https://pytorch.org/tutorials/beginner/nlp/advanced_tutorial.html.
#
# Because each time we only feed one sentence into the model, the sequence length for the input of LSTM can be different. Pytorch will handle this automatically.

# %% [markdown]
# ## Example

# %%
# Author: Robert Guthrie

import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim

torch.manual_seed(1)

# %% [markdown]
# ### Helper functions to make the code more readable.

# %%
def argmax(vec):
    # return the argmax as a python int
    _, idx = torch.max(vec, 1)
    return idx.item()


def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)


# Compute log sum exp in a numerically stable way for the forward algorithm
def log_sum_exp(vec):
    max_score = vec[0, argmax(vec)]
    max_score_broadcast = max_score.view(1, -1).expand(1, vec.size()[1])
    return max_score + \
        torch.log(torch.sum(torch.exp(vec - max_score_broadcast)))

# %% [markdown]
# ### Create model

# %%
class BiLSTM_CRF(nn.Module):

    def __init__(self, vocab_size, tag_to_ix, embedding_dim, hidden_dim):
        super(BiLSTM_CRF, self).__init__()
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.vocab_size = vocab_size
        self.tag_to_ix = tag_to_ix
        self.tagset_size = len(tag_to_ix)

        self.word_embeds = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim // 2,
                            num_layers=1, bidirectional=True)

        # Maps the output of the LSTM into tag space.
        self.hidden2tag = nn.Linear(hidden_dim, self.tagset_size)

        # Matrix of transition parameters.  Entry i,j is the score of
        # transitioning *to* i *from* j.
        self.transitions = nn.Parameter(
            torch.randn(self.tagset_size, self.tagset_size))

        # These two statements enforce the constraint that we never transfer
        # to the start tag and we never transfer from the stop tag
        self.transitions.data[tag_to_ix[START_TAG], :] = -10000
        self.transitions.data[:, tag_to_ix[STOP_TAG]] = -10000

        self.hidden = self.init_hidden()

    def init_hidden(self):
        return (torch.randn(2, 1, self.hidden_dim // 2),
                torch.randn(2, 1, self.hidden_dim // 2))

    def _forward_alg(self, feats):
        # Do the forward algorithm to compute the partition function
        init_alphas = torch.full((1, self.tagset_size), -10000.)
        # START_TAG has all of the score.
        init_alphas[0][self.tag_to_ix[START_TAG]] = 0.

        # Wrap in a variable so that we will get automatic backprop
        forward_var = init_alphas

        # Iterate through the sentence
        for feat in feats:
            alphas_t = []  # The forward tensors at this timestep
            for next_tag in range(self.tagset_size):
                # broadcast the emission score: it is the same regardless of
                # the previous tag
                emit_score = feat[next_tag].view(
                    1, -1).expand(1, self.tagset_size)
                # the ith entry of trans_score is the score of transitioning to
                # next_tag from i
                trans_score = self.transitions[next_tag].view(1, -1)
                # The ith entry of next_tag_var is the value for the
                # edge (i -> next_tag) before we do log-sum-exp
                next_tag_var = forward_var + trans_score + emit_score
                # The forward variable for this tag is log-sum-exp of all the
                # scores.
                alphas_t.append(log_sum_exp(next_tag_var).view(1))
            forward_var = torch.cat(alphas_t).view(1, -1)
        terminal_var = forward_var + self.transitions[self.tag_to_ix[STOP_TAG]]
        alpha = log_sum_exp(terminal_var)
        return alpha

    def _get_lstm_features(self, sentence):
        self.hidden = self.init_hidden()
        embeds = self.word_embeds(sentence).view(len(sentence), 1, -1)
        lstm_out, self.hidden = self.lstm(embeds, self.hidden)
        lstm_out = lstm_out.view(len(sentence), self.hidden_dim)
        lstm_feats = self.hidden2tag(lstm_out)
        return lstm_feats

    def _score_sentence(self, feats, tags):
        # Gives the score of a provided tag sequence
        score = torch.zeros(1)
        tags = torch.cat([torch.tensor([self.tag_to_ix[START_TAG]], dtype=torch.long), tags])
        for i, feat in enumerate(feats):
            score = score + \
                self.transitions[tags[i + 1], tags[i]] + feat[tags[i + 1]]
        score = score + self.transitions[self.tag_to_ix[STOP_TAG], tags[-1]]
        return score

    def _viterbi_decode(self, feats):
        backpointers = []

        # Initialize the viterbi variables in log space
        init_vvars = torch.full((1, self.tagset_size), -10000.)
        init_vvars[0][self.tag_to_ix[START_TAG]] = 0

        # forward_var at step i holds the viterbi variables for step i-1
        forward_var = init_vvars
        for feat in feats:
            bptrs_t = []  # holds the backpointers for this step
            viterbivars_t = []  # holds the viterbi variables for this step

            for next_tag in range(self.tagset_size):
                # next_tag_var[i] holds the viterbi variable for tag i at the
                # previous step, plus the score of transitioning
                # from tag i to next_tag.
                # We don't include the emission scores here because the max
                # does not depend on them (we add them in below)
                next_tag_var = forward_var + self.transitions[next_tag]
                best_tag_id = argmax(next_tag_var)
                bptrs_t.append(best_tag_id)
                viterbivars_t.append(next_tag_var[0][best_tag_id].view(1))
            # Now add in the emission scores, and assign forward_var to the set
            # of viterbi variables we just computed
            forward_var = (torch.cat(viterbivars_t) + feat).view(1, -1)
            backpointers.append(bptrs_t)

        # Transition to STOP_TAG
        terminal_var = forward_var + self.transitions[self.tag_to_ix[STOP_TAG]]
        best_tag_id = argmax(terminal_var)
        path_score = terminal_var[0][best_tag_id]

        # Follow the back pointers to decode the best path.
        best_path = [best_tag_id]
        for bptrs_t in reversed(backpointers):
            best_tag_id = bptrs_t[best_tag_id]
            best_path.append(best_tag_id)
        # Pop off the start tag (we dont want to return that to the caller)
        start = best_path.pop()
        assert start == self.tag_to_ix[START_TAG]  # Sanity check
        best_path.reverse()
        return path_score, best_path

    def neg_log_likelihood(self, sentence, tags):
        feats = self._get_lstm_features(sentence)
        forward_score = self._forward_alg(feats)
        gold_score = self._score_sentence(feats, tags)
        return forward_score - gold_score

    def forward(self, sentence):  # dont confuse this with _forward_alg above.
        # Get the emission scores from the BiLSTM
        lstm_feats = self._get_lstm_features(sentence)

        # Find the best path, given the features.
        score, tag_seq = self._viterbi_decode(lstm_feats)
        return score, tag_seq

# %% [markdown]
# ### Run training

# %%
START_TAG = "<START>"
STOP_TAG = "<STOP>"
EMBEDDING_DIM = 5
HIDDEN_DIM = 4

# Make up some training data
training_data = [(
    "the wall street journal reported today that apple corporation made money".split(),
    "B I I I O O O B I O O".split()
), (
    "georgia tech is a university in georgia".split(),
    "B I O O O O B".split()
)]

word_to_ix = {}
for sentence, tags in training_data:
    for word in sentence:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)

tag_to_ix = {"B": 0, "I": 1, "O": 2, START_TAG: 3, STOP_TAG: 4}

model = BiLSTM_CRF(len(word_to_ix), tag_to_ix, EMBEDDING_DIM, HIDDEN_DIM)
optimizer = optim.SGD(model.parameters(), lr=0.01, weight_decay=1e-4)

# Check predictions before training
with torch.no_grad():
    precheck_sent = prepare_sequence(training_data[0][0], word_to_ix)
    precheck_tags = torch.tensor([tag_to_ix[t] for t in training_data[0][1]], dtype=torch.long)
    print(model(precheck_sent))

# Make sure prepare_sequence from earlier in the LSTM section is loaded
for epoch in range(300):  # again, normally you would NOT do 300 epochs, it is toy data
    for sentence, tags in training_data:
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()

        # Step 2. Get our inputs ready for the network, that is,
        # turn them into Tensors of word indices.
        sentence_in = prepare_sequence(sentence, word_to_ix)
        targets = torch.tensor([tag_to_ix[t] for t in tags], dtype=torch.long)

        # Step 3. Run our forward pass.
        loss = model.neg_log_likelihood(sentence_in, targets)

        # Step 4. Compute the loss, gradients, and update the parameters by
        # calling optimizer.step()
        loss.backward()
        optimizer.step()

# Check predictions after training
with torch.no_grad():
    precheck_sent = prepare_sequence(training_data[0][0], word_to_ix)
    print(model(precheck_sent))
# We got it!
# Out:
# (tensor(2.6907), [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1])
# (tensor(20.4906), [0, 1, 1, 1, 2, 2, 2, 0, 1, 2, 2])

# %% [markdown]
# # Exercise

# %% [markdown]
# ## E1. Multiple Choice Questions
# ***Please check the following Ed Q Link.***
#
# E1 (Ed Q Link): https://edstem.org/au/courses/7951/lessons/21484/slides/152424

# %% [markdown]
# ## E2. Try Bi-LSTM with CRF!
#
# Now we will apply the Bi-LSTM CRF model we just learned to CoNLL 2003 NER dataset using the pretrained glove embeddings. Please go through and complete the [Function for accuracy] section.
#
# **NOTE: You MUST make sure you can successfully run all the follow-up sections after the [Function for accuracy] section, including the [Initialize Model], [Train the model] and [Testing] sections. And please KEEP the running log for submission.**

# %% [markdown]
# ### Download Dataset

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate
drive = None
def authenticate():
    global drive
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)

#Download files
def downloadFiles(fileIds):
    authenticate()
    for fileId in fileIds:    
        downloaded = drive.CreateFile({"id": fileId[1]})
        downloaded.GetContentFile(fileId[0])

# %%
#Download file if not existing
try:
  _ = open("train.txt", "r")
except:
  downloadFiles([["train.txt", "1UmNHdUZxjfcuIzCcAKuBvfBXdSWFv47i"]])

try:
  _ = open("validation.txt", "r")
except:
  downloadFiles([["validation.txt", "11bZIh5V9m2nZJ5s5xQ_gxHEHkAEhV8eQ"]])

try:
  _ = open("test.txt", "r")
except:
  downloadFiles([["test.txt", "1V-LQuJWT62aCytYuhZuaxvICsqiF1rdK"]])

# %%
def read_data(file_name, n_sample):
    f = open(file_name)
    documents = f.readlines()

    input_data = []
    target_data = []

    temp1 = []
    temp2 = []
    for i in documents:
        if i == '\n':
            input_data.append(temp1)
            target_data.append(temp2)
            temp1 = []
            temp2 = []
        else:
            temp1.append(i.replace('\n','').split(' ')[0].lower())
            temp2.append(i.replace('\n','').split(' ')[3])
    return input_data[:n_sample], target_data[:n_sample]

train_data, target_y_train = read_data("train.txt",400)
validation_data, target_y_validation = read_data("validation.txt",50)
test_data, target_y_test = read_data("test.txt",50)

# %%
print(len(train_data))
print(train_data[1])
print(target_y_train[1])
# Out:
# 400
# ['eu', 'rejects', 'german', 'call', 'to', 'boycott', 'british', 'lamb', '.']
# ['I-ORG', 'O', 'I-MISC', 'O', 'O', 'O', 'I-MISC', 'O', 'O']

# %% [markdown]
# ### Preprocess

# %% [markdown]
# #### Generate word_to_ix and tag_to_ix

# %%
word_to_ix = {}
for sentence in train_data+validation_data+test_data:
    for word in sentence:
        word = word.lower()
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
word_list = list(word_to_ix.keys())

START_TAG = "<START>"
STOP_TAG = "<STOP>"
tag_to_ix = {START_TAG:0, STOP_TAG:1}
for tags in target_y_train+target_y_validation:
    for tag in tags:
        if tag not in tag_to_ix:
            tag_to_ix[tag] = len(tag_to_ix)

# %% [markdown]
# #### Generate Embedding Matrix

# %%
import gensim.downloader as api
word_emb_model = api.load("glove-twitter-25") 

EMBEDDING_DIM = 25

embedding_matrix = []
for word in word_list:
    try:
        embedding_matrix.append(word_emb_model.wv[word])
    except:
        embedding_matrix.append([0]*EMBEDDING_DIM)
embedding_matrix = np.array(embedding_matrix)
embedding_matrix.shape
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   if __name__ == '__main__':
# (2351, 25)

# %% [markdown]
# #### convert dataset into idxs

# %%
def to_index(data, to_ix):
    input_index_list = []
    for sent in data:
        input_index_list.append([to_ix[w] for w in sent])
    return input_index_list

train_input_index =  to_index(train_data,word_to_ix)
train_output_index = to_index(target_y_train,tag_to_ix)
val_input_index = to_index(validation_data,word_to_ix)
val_output_index = to_index(target_y_validation,tag_to_ix)
test_input_index = to_index(test_data,word_to_ix)
test_output_index = to_index(target_y_test,tag_to_ix)

# %% [markdown]
# ### Model

# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim

torch.manual_seed(1)

def argmax(vec):
    # return the argmax as a python int
    _, idx = torch.max(vec, 1)
    return idx.item()


# Compute log sum exp in a numerically stable way for the forward algorithm
def log_sum_exp(vec):
    max_score = vec[0, argmax(vec)]
    max_score_broadcast = max_score.view(1, -1).expand(1, vec.size()[1])
    return max_score + \
        torch.log(torch.sum(torch.exp(vec - max_score_broadcast)))

class BiLSTM_CRF(nn.Module):

    def __init__(self, vocab_size, tag_to_ix, embedding_dim, hidden_dim):
        super(BiLSTM_CRF, self).__init__()
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.vocab_size = vocab_size
        self.tag_to_ix = tag_to_ix
        self.tagset_size = len(tag_to_ix)

        self.word_embeds = nn.Embedding(vocab_size, embedding_dim)

        """Here we use the embedding matrix as the initial weights of nn.Embedding"""
        self.word_embeds.weight.data.copy_(torch.from_numpy(embedding_matrix))
        
        self.lstm = nn.LSTM(embedding_dim, hidden_dim // 2,
                            num_layers=1, bidirectional=True)

        # Maps the output of the LSTM into tag space.
        self.hidden2tag = nn.Linear(hidden_dim, self.tagset_size)

        # Matrix of transition parameters.  Entry i,j is the score of
        # transitioning *to* i *from* j.
        self.transitions = nn.Parameter(
            torch.randn(self.tagset_size, self.tagset_size))

        # These two statements enforce the constraint that we never transfer
        # to the start tag and we never transfer from the stop tag
        self.transitions.data[tag_to_ix[START_TAG], :] = -10000
        self.transitions.data[:, tag_to_ix[STOP_TAG]] = -10000

        self.hidden = self.init_hidden()

    def init_hidden(self):
        return (torch.randn(2, 1, self.hidden_dim // 2).to(device),
                torch.randn(2, 1, self.hidden_dim // 2).to(device))

    def _forward_alg(self, feats):
        # Do the forward algorithm to compute the partition function
        init_alphas = torch.full((1, self.tagset_size), -10000.).to(device)
        # START_TAG has all of the score.
        init_alphas[0][self.tag_to_ix[START_TAG]] = 0.

        # Wrap in a variable so that we will get automatic backprop
        forward_var = init_alphas

        # Iterate through the sentence
        for feat in feats:
            alphas_t = []  # The forward tensors at this timestep
            for next_tag in range(self.tagset_size):
                # broadcast the emission score: it is the same regardless of
                # the previous tag
                emit_score = feat[next_tag].view(
                    1, -1).expand(1, self.tagset_size)
                # the ith entry of trans_score is the score of transitioning to
                # next_tag from i
                trans_score = self.transitions[next_tag].view(1, -1)
                # The ith entry of next_tag_var is the value for the
                # edge (i -> next_tag) before we do log-sum-exp
                next_tag_var = forward_var + trans_score + emit_score
                # The forward variable for this tag is log-sum-exp of all the
                # scores.
                alphas_t.append(log_sum_exp(next_tag_var).view(1))
            forward_var = torch.cat(alphas_t).view(1, -1)
        terminal_var = forward_var + self.transitions[self.tag_to_ix[STOP_TAG]]
        alpha = log_sum_exp(terminal_var)
        return alpha

    def _get_lstm_features(self, sentence):
        self.hidden = self.init_hidden()
        embeds = self.word_embeds(sentence).view(len(sentence), 1, -1)
        lstm_out, self.hidden = self.lstm(embeds, self.hidden)
        lstm_out = lstm_out.view(len(sentence), self.hidden_dim)
        lstm_feats = self.hidden2tag(lstm_out)
        return lstm_feats

    def _score_sentence(self, feats, tags):
        # Gives the score of a provided tag sequence
        score = torch.zeros(1).to(device)
        tags = torch.cat([torch.tensor([self.tag_to_ix[START_TAG]], dtype=torch.long).to(device), tags])
        for i, feat in enumerate(feats):
            score = score + \
                self.transitions[tags[i + 1], tags[i]] + feat[tags[i + 1]]
        score = score + self.transitions[self.tag_to_ix[STOP_TAG], tags[-1]]
        return score

    def _viterbi_decode(self, feats):
        backpointers = []

        # Initialize the viterbi variables in log space
        init_vvars = torch.full((1, self.tagset_size), -10000.).to(device)
        init_vvars[0][self.tag_to_ix[START_TAG]] = 0

        # forward_var at step i holds the viterbi variables for step i-1
        forward_var = init_vvars
        for feat in feats:
            bptrs_t = []  # holds the backpointers for this step
            viterbivars_t = []  # holds the viterbi variables for this step

            for next_tag in range(self.tagset_size):
                # next_tag_var[i] holds the viterbi variable for tag i at the
                # previous step, plus the score of transitioning
                # from tag i to next_tag.
                # We don't include the emission scores here because the max
                # does not depend on them (we add them in below)
                next_tag_var = forward_var + self.transitions[next_tag]
                best_tag_id = argmax(next_tag_var)
                bptrs_t.append(best_tag_id)
                viterbivars_t.append(next_tag_var[0][best_tag_id].view(1))
            # Now add in the emission scores, and assign forward_var to the set
            # of viterbi variables we just computed
            forward_var = (torch.cat(viterbivars_t) + feat).view(1, -1)
            backpointers.append(bptrs_t)

        # Transition to STOP_TAG
        terminal_var = forward_var + self.transitions[self.tag_to_ix[STOP_TAG]]
        best_tag_id = argmax(terminal_var)
        path_score = terminal_var[0][best_tag_id]

        # Follow the back pointers to decode the best path.
        best_path = [best_tag_id]
        for bptrs_t in reversed(backpointers):
            best_tag_id = bptrs_t[best_tag_id]
            best_path.append(best_tag_id)
        # Pop off the start tag (we dont want to return that to the caller)
        start = best_path.pop()
        assert start == self.tag_to_ix[START_TAG]  # Sanity check
        best_path.reverse()
        return path_score, best_path

    def neg_log_likelihood(self, sentence, tags):
        feats = self._get_lstm_features(sentence)
        forward_score = self._forward_alg(feats)
        gold_score = self._score_sentence(feats, tags)
        return forward_score - gold_score

    def forward(self, sentence):  # dont confuse this with _forward_alg above.
        # Get the emission scores from the BiLSTM
        lstm_feats = self._get_lstm_features(sentence)

        # Find the best path, given the features.
        score, tag_seq = self._viterbi_decode(lstm_feats)
        return score, tag_seq

# %% [markdown]
# #### Function for accuracy [Please Complete this part]

# %% [markdown]
# Please complete the *cal_acc* function that generates the model predictions using the input data and calculates the accuracy by comparing the model predictions with the ground truth labels. You can refer to the [Train the model] section regarding what the inputs and outputs are and how they will be used.
#
# **Hint**: You are going to test the "model" using "input_index"(whose shape is (num_samples, seq_length)), and you are going to return three variables:
# - **predicted**: This should be a list, and each item in the list should be the predicted NER label for a word. Suppose you have two sentences, sentence 1 has 8 words and sentence 2 has 6 words. This list should have 14(=8+6) items.
# - **ground_truth**: This should also be a list, and each item in the list should be the actual NER label for a word, which can be easily gotten from "output_index". Suppose you have two sentences, sentence 1 has 8 words and sentence 2 has 6 words. This list should have 14(=8+6) items.
# - **accuracy**: You are going to use "predicted" and "ground_truth" to calculate the accuracy.

# %%
import numpy as np
def cal_acc(model, input_index, output_index):

    return predicted, ground_truth, accuracy

# %% [markdown]
# #### Initialize Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
HIDDEN_DIM = 50

model = BiLSTM_CRF(len(word_to_ix), tag_to_ix, EMBEDDING_DIM, HIDDEN_DIM).to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, weight_decay=1e-4)

# %% [markdown]
# #### Train the model

# %%
"""Each epoch will take about 1-2 minutes"""

import datetime

for epoch in range(20):  
    time1 = datetime.datetime.now()
    train_loss = 0

    model.train()
    for i, idxs in enumerate(train_input_index):
        tags_index = train_output_index[i]

        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()

        # Step 2. Get our inputs ready for the network, that is,
        # turn them into Tensors of word indices.
        sentence_in = torch.tensor(idxs, dtype=torch.long).to(device)
        targets = torch.tensor(tags_index, dtype=torch.long).to(device)

        # Step 3. Run our forward pass.
        loss = model.neg_log_likelihood(sentence_in, targets)

        # Step 4. Compute the loss, gradients, and update the parameters by
        # calling optimizer.step()
        loss.backward()
        optimizer.step()

        train_loss+=loss.item()

    model.eval()
    # Call the cal_acc functions you implemented as required
    _, _, train_acc = cal_acc(model,train_input_index,train_output_index)
    _, _, val_acc = cal_acc(model,val_input_index,val_output_index)

    val_loss = 0
    for i, idxs in enumerate(val_input_index):
        tags_index = val_output_index[i]
        sentence_in = torch.tensor(idxs, dtype=torch.long).to(device)
        targets = torch.tensor(tags_index, dtype=torch.long).to(device)
        loss = model.neg_log_likelihood(sentence_in, targets)
        val_loss+=loss.item()
    time2 = datetime.datetime.now()

    print("Epoch:%d, Training loss: %.2f, train acc: %.4f, val loss: %.2f, val acc: %.4f, time: %.2fs" %(epoch+1, train_loss,train_acc, val_loss, val_acc, (time2-time1).total_seconds()))

# The log below is the sample output for this section
# Please make sure you keep your own running log for submission
# Out:
# Epoch:1, Training loss: 1989.92, train acc: 0.8919, val loss: 427.17, val acc: 0.8182, time: 48.71s
# Epoch:2, Training loss: 1553.81, train acc: 0.9072, val loss: 439.65, val acc: 0.8281, time: 44.66s
# Epoch:3, Training loss: 1321.50, train acc: 0.9176, val loss: 442.58, val acc: 0.8269, time: 45.18s
# Epoch:4, Training loss: 1155.77, train acc: 0.9232, val loss: 456.69, val acc: 0.8257, time: 52.41s
# Epoch:5, Training loss: 1038.87, train acc: 0.9288, val loss: 463.93, val acc: 0.8244, time: 43.05s
# Epoch:6, Training loss: 936.20, train acc: 0.9386, val loss: 468.58, val acc: 0.8306, time: 43.29s
# Epoch:7, Training loss: 825.67, train acc: 0.9459, val loss: 471.95, val acc: 0.8331, time: 43.96s
# Epoch:8, Training loss: 731.20, train acc: 0.9516, val loss: 477.97, val acc: 0.8319, time: 43.49s
# Epoch:9, Training loss: 659.31, train acc: 0.9573, val loss: 486.06, val acc: 0.8381, time: 43.33s
# Epoch:10, Training loss: 573.50, train acc: 0.9635, val loss: 476.00, val acc: 0.8418, time: 43.03s
# Epoch:11, Training loss: 507.70, train acc: 0.9686, val loss: 486.33, val acc: 0.8431, time: 42.82s
# Epoch:12, Training loss: 437.10, train acc: 0.9748, val loss: 488.79, val acc: 0.8468, time: 42.82s
# Epoch:13, Training loss: 410.66, train acc: 0.9776, val loss: 489.17, val acc: 0.8443, time: 43.94s
# Epoch:14, Training loss: 350.02, train acc: 0.9779, val loss: 508.95, val acc: 0.8481, time: 43.78s
# Epoch:15, Training loss: 316.79, train acc: 0.9842, val loss: 516.67, val acc: 0.8456, time: 44.07s
# Epoch:16, Training loss: 287.29, train acc: 0.9852, val loss: 524.78, val acc: 0.8456, time: 44.48s
# Epoch:17, Training loss: 248.31, train acc: 0.9876, val loss: 522.35, val acc: 0.8506, time: 44.15s
# Epoch:18, Training loss: 244.71, train acc: 0.9876, val loss: 554.96, val acc: 0.8531, time: 44.18s
# Epoch:19, Training loss: 200.05, train acc: 0.9871, val loss: 534.73, val acc: 0.8506, time: 42.96s
# Epoch:20, Training loss: 178.04, train acc: 0.9856, val loss: 546.89, val acc: 0.8568, time: 43.08s

# %% [markdown]
# ### Testing

# %%
# Call the cal_acc functions you implemented as required
y_pred, y_true, _ = cal_acc(model,test_input_index,test_output_index)

def decode_output(output_list):
    ix_to_tag = {v:k for k,v in tag_to_ix.items()}
    return [ix_to_tag[output] for output in output_list]

y_true_decode = decode_output(y_true)
y_pred_decode = decode_output(y_pred)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true_decode,y_pred_decode,digits=4))
# The log below is the sample output for this section
# Please make sure you keep your own running log for submission
# Out:
#               precision    recall  f1-score   support
#
#        I-LOC     0.9545    0.9333    0.9438        45
#       I-MISC     0.7600    0.7600    0.7600        25
#        I-ORG     0.0000    0.0000    0.0000         3
#        I-PER     0.9151    0.7698    0.8362       126
#            O     0.9590    0.9864    0.9725       806
#
#     accuracy                         0.9483      1005
#    macro avg     0.7177    0.6899    0.7025      1005
# weighted avg     0.9455    0.9483    0.9459      1005
